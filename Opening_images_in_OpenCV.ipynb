# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %% [markdown]
# # EXTRACTING FILE BY PATH

# %%
img = cv2.imread('Downloads/IMAGES/autumn-nature-landscape-colorful-forest-autumn-nature-landscape-colorful-forest-morning-sunlight-131400332.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
## if we don't give proper path of a file ,then we will come across error like NoneType when we check type of variable

# %%
img
# Out:
# array([[[20, 26, 31],
#         [19, 30, 34],
#         [15, 30, 33],
#         ...,
#         [34, 20, 24],
#         [34, 18, 25],
#         [36, 20, 27]],
#
#        [[40, 49, 53],
#         [20, 32, 36],
#         [25, 42, 45],
#         ...,
#         [34, 20, 24],
#         [34, 19, 23],
#         [36, 21, 25]],
#
#        [[38, 50, 56],
#         [32, 47, 50],
#         [42, 63, 65],
#         ...,
#         [35, 20, 24],
#         [34, 19, 23],
#         [36, 21, 25]],
#
#        ...,
#
#        [[30, 18, 30],
#         [31, 19, 31],
#         [31, 21, 33],
#         ...,
#         [13, 36, 68],
#         [ 5, 30, 62],
#         [13, 38, 70]],
#
#        [[ 7, 48, 43],
#         [10, 50, 45],
#         [ 2, 39, 35],
#         ...,
#         [13, 32, 47],
#         [ 8, 30, 42],
#         [11, 33, 45]],
#
#        [[14, 55, 50],
#         [23, 63, 58],
#         [20, 57, 53],
#         ...,
#         [13, 32, 47],
#         [ 7, 29, 41],
#         [ 9, 31, 43]]], dtype=uint8)

# %%
img.shape
# Out:
# (450, 800, 3)

# %% [markdown]
# # DISPLAYING IMAGE

# %%
plt.imshow(img)

# %%
# IN MATPLOTLIB-------->COLORING PATTERN IS---------->RGB RED GREEN BLUE
# IN OPENCV----------->COLORING PATTERN IS----------->BGR BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %% [markdown]
# # CONVERT ORIGNAL IMAGE ON GRAY SCALE

# %%
img_gray = cv2.imread('Downloads/IMAGES/autumn-nature-landscape-colorful-forest-autumn-nature-landscape-colorful-forest-morning-sunlight-131400332.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (450, 800)

# %%
img_gray
# Out:
# array([[27, 30, 29, ..., 23, 22, 24],
#        [49, 32, 41, ..., 23, 22, 24],
#        [50, 46, 61, ..., 23, 22, 24],
#        ...,
#        [23, 24, 26, ..., 43, 37, 45],
#        [42, 44, 34, ..., 34, 31, 34],
#        [49, 57, 52, ..., 34, 30, 32]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %% [markdown]
# # GRAY SCALE IMAGE VISUALIZATION

# %%
plt.imshow(img_gray, cmap = 'gray')

# %% [markdown]
# # RESIZING IMAGES

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img) # This is Original Image

# %%
fix_img.shape
# Out:
# (450, 800, 3)

# %%
new_img = cv2.resize(fix_img, (399,400))

# %%
plt.imshow(new_img)

# %%
# RESIZE IMAGES BY RATIO

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (225, 400, 3)

# %% [markdown]
# # FLIP IMAGES

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
new_img_1 = cv2.flip(fix_img,1)
plt.imshow(new_img_1)

# %%
new_img_2 = cv2.flip(fix_img, -1)
plt.imshow(new_img_2)

# %% [markdown]
# # SAVE IMAGE BY OPENCV

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %% [markdown]
# # FILLING IMAGE IN NOTEBOOK

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %% [markdown]
# # GREAT JOB!
