# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create 5*5 array where every elements is a 10

# %%
arr = np.ones((5,5))

# %%
arr * 10
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
# Run the cell below to create of a random array of random numbers and see if you can figure out how it works.

# %%
np.random.seed(101)
arr = np.random.randint(low = 0, high = 100, size=(5*5))
arr
# Out:
# array([95, 11, 81, 70, 63, 87, 75,  9, 77, 40,  4, 63, 40, 60, 92, 64,  5,
#        12, 93, 40, 49, 83,  8, 29, 59])

# %%
# What is largest and smallest value in the array

# %%
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %% [markdown]
# # DISPLAY IMAGE

# %%
from PIL import Image

# %%
img = Image.open('Downloads/808683.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x24D115246A0>

# %%
# Convert image into array

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.asarray(img)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (1080, 1920, 3)

# %%
# Use slicing technique to set RED and GREEN channel of the image to 0, then show isolated blue.

# %%
plt.imshow(arr)

# %%
mycopy = arr.copy()

# %%
# R G B
# RED TO 0
mycopy[:,:, 0] = 0

# %%
plt.imshow(mycopy)

# %%
# GREEN TO 0
mycopy[:,:,1] = 0

# %%
plt.imshow(mycopy)

# %% [markdown]
# # Great Job!
