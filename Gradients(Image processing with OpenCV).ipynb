# %% [markdown]
# # Import Dependencies

# %%
import cv2
import pandas
import warnings
import numpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ##### Displaying Image Function

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap = 'gray')

# %% [markdown]
# ##### Load Image

# %%
img = cv2.imread('maxresdefault.jpg',0)

# %% [markdown]
# ##### Displaying Image

# %%
display_img(img)

# %% [markdown]
# ##### Applying Sobel Filter

# %%
sobelx = cv2.Sobel(img,cv2.CV_64F, 1,0,ksize = 5)

# %%
display_img(sobelx)

# %% [markdown]
# ### Note: In above pic we are watching vertical line clearly.

# %%
sobely = cv2.Sobel(img,cv2.CV_64F, 0,1,ksize = 5)

# %%
display_img(sobely)

# %% [markdown]
# ### Note: In above pic we are clearly viewing horizental line.

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F)

# %%
display_img(laplacian)

# %% [markdown]
# ##### Blending Images

# %%
blended_img = cv2.addWeighted(src1 = sobelx, alpha =0.5, src2 = sobely, beta = 0.5, gamma = 0)

# %%
display_img(blended_img)

# %% [markdown]
# ##### Thresold Image

# %%
ret, thi = cv2.threshold(img,cv2.THRESH_BINARY, 100,255)

# %%
display_img(thi)

# %%
kernal = np.ones((4,4),np.uint8)

# %%
gradient = cv2.morphologyEx(blended_img,cv2.MORPH_GRADIENT, kernal)

# %%
display_img(gradient)

# %% [markdown]
# # Great Job!
